# %%
# Just to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # read data set

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # see columns head

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # understand the number of features and data entries

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# # Let's look at high correlation features

# %%
features = ['price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront',
           'view','condition','grade','sqft_above','sqft_basement','yr_built','yr_renovated',
           'zipcode','lat','long','sqft_living15','sqft_lot15']

mask = np.zeros_like(df[features].corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(df[features].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse
           linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": 1});

# %% [markdown]
# # High correlated features:
# # 'bathrooms', 'bedrooms', 'sqft_living', 'grade', 'view', 'sqft_above', 'sqft_living15', 'sqft_lot' 'sqft_basement'

# %%
df.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %% [markdown]
# # Let's group and analize by features

# %%
df.groupby('bedrooms').size()
# Out:
# bedrooms
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# dtype: int64

# %%
sns.countplot(x=df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df = df[df['bedrooms'] > 0.5]

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  8,  9, 11, 10, 33], dtype=int64)

# %%
0 in df['bedrooms'].unique()
# Out:
# False

# %% [markdown]
# # Delete bedrooms >=6

# %%
#indexNames = df[ (df['bedrooms'] >= 6) & (df['bedrooms'] <= 33) ].index
#df.drop(indexNames , inplace=True)

# %%
sns.boxplot(df.bedrooms, df.price)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.groupby('bathrooms').size()
# Out:
# bathrooms
# 0.00       3
# 0.50       4
# 0.75      71
# 1.00    3851
# 1.25       9
# 1.50    1445
# 1.75    3048
# 2.00    1930
# 2.25    2047
# 2.50    5377
# 2.75    1185
# 3.00     753
# 3.25     589
# 3.50     731
# 3.75     155
# 4.00     136
# 4.25      79
# 4.50     100
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 5.75       4
# 6.00       6
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# 8.00       2
# dtype: int64

# %%
sns.countplot(x=df['bathrooms'])
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='count'>

# %%
df = df[df['bathrooms'] > 1.0]

# %%
df['bathrooms'].unique()
# Out:
# array([2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  , 3.5 ,
#        4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 5.5 , 6.75, 5.75, 8.  ,
#        7.5 , 7.75, 6.25, 6.5 ])

# %%
df = df[df['bathrooms']!=0]

# %%
0 in df['bathrooms'].unique()
# Out:
# False

# %%
plt.scatter(df.bathrooms, df.price)

# %% [markdown]
# # Delete bathrooms > 4.75

# %%
#indexNames = df[ (df['bathrooms'] >= 4.75) & (df['bathrooms'] <= 8.0) ].index
#df.drop(indexNames , inplace=True)

# %%
sns.boxplot(df.bathrooms, df.price)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
df.groupby('sqft_living').size()
# Out:
# sqft_living
# 590      1
# 680      1
# 690      1
# 710      1
# 720      4
#         ..
# 9640     1
# 9890     1
# 10040    1
# 12050    1
# 13540    1
# Length: 985, dtype: int64

# %%
plt.scatter(df.sqft_living, df.price)

# %%
plt.scatter(df.sqft_living15, df.price)

# %% [markdown]
# # Drop sqft_living15

# %%
df.groupby('grade').size()
# Out:
# grade
# 4        1
# 5       37
# 6      596
# 7     6873
# 8     5921
# 9     2608
# 10    1134
# 11     399
# 12      89
# 13      13
# dtype: int64

# %%
sns.countplot(x=df['grade'])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
df = df[df['grade'] > 5]

# %%
df['grade'].unique()
# Out:
# array([ 7,  8, 11,  9,  6, 10, 12, 13], dtype=int64)

# %%
#indexNames = df[ (df['grade'] >= 11) & (df['grade'] <= 13) ].index
#df.drop(indexNames , inplace=True)

# %%
sns.boxplot(df.grade, df.price)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
df.groupby('sqft_above').size()
# Out:
# sqft_above
# 580     5
# 590     2
# 600     3
# 610     3
# 620     3
#        ..
# 7880    1
# 8020    1
# 8570    1
# 8860    1
# 9410    1
# Length: 904, dtype: int64

# %%
plt.scatter(df.sqft_above, df.price)

# %%
df.groupby('sqft_basement').size()
# Out:
# sqft_basement
# 0       9955
# 10         2
# 20         1
# 40         4
# 50        10
#         ...
# 3260       1
# 3480       1
# 3500       1
# 4130       1
# 4820       1
# Length: 305, dtype: int64

# %%
plt.scatter(df.sqft_basement, df.price)

# %%
df.groupby('sqft_lot').size()
# Out:
# sqft_lot
# 520        1
# 572        1
# 600        1
# 609        1
# 635        1
#           ..
# 920423     1
# 982278     1
# 982998     1
# 1024068    1
# 1074218    1
# Length: 8987, dtype: int64

# %%
plt.scatter(df.sqft_lot, df.price)

# %%
df.groupby('view').size()
# Out:
# view
# 0    15689
# 1      298
# 2      866
# 3      482
# 4      298
# dtype: int64

# %%
plt.scatter(df.view, df.price)

# %%
df.groupby('floors').size()
# Out:
# floors
# 1.0    7462
# 1.5    1274
# 2.0    8125
# 2.5     158
# 3.0     607
# 3.5       7
# dtype: int64

# %%
sns.countplot(x=df['floors'])
# Out:
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
plt.scatter(df.floors, df.price)

# %% [markdown]
# # Consider six features: 'bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_basement'

# %%
#['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#       'lat', 'long', 'sqft_living15', 'sqft_lot15']

x=df.drop(["id", "date", "price", "sqft_lot", "floors", "waterfront", "view", "condition",  "yr_built", "yr_renovated",  "zipcode", "lat", "long", "sqft_living15", "sqft_lot15"], axis=1) #features
y=df["price"] #target
x.shape
# Out:
# (17633, 6)

# %%
x.isnull().sum() #gives null values in a df
x.isnull().values.any() #gives yes or no if null is present indf
# Out:
# False

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df = df[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_basement','price']]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # split and train the model

# %%
x = df[['bedrooms','bathrooms','sqft_living','grade','sqft_above','sqft_basement']]
y = df['price']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10)

# %% [markdown]
# # Linear Regression

# %%
LM = LinearRegression()
LM.fit(x_train,y_train)
y_pred = LM.predict(x_test)
LM_r2 = r2_score(y_test, y_pred)
LM_MSE = mean_squared_error (y_test, y_pred)
LM_inter = LM.intercept_
print("R2 score:", LM_r2)
print("MSE:", LM_MSE)
print(LM_inter)
# Out:
# R2 score: 0.5450421227522051
# MSE: 68001006664.22596
# -756558.9246823956

# %%
coeff_df = pd.DataFrame(LM.coef_,x.columns,columns=['LM_Coefficient'])
coeff_df
# Out:
#                LM_Coefficient
# bedrooms        -3.281921e+04
# bathrooms        1.747693e+04
# sqft_living     -2.718773e+15
# grade            1.221572e+05
# sqft_above       2.718773e+15
# sqft_basement    2.718773e+15

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("LM Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'LM Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %%
sns.distplot((y_test-y_pred),bins=50);

# %%
results = pd.DataFrame({'Model' : ["LM"], "r2_score" :[LM_r2], "mean_squared_error" :[LM_MSE], "intercept" :[LM_inter]})
results.sort_values(by="r2_score",  ascending=False)
# Out:
#   Model  r2_score  mean_squared_error      intercept
# 0    LM  0.545042        6.800101e+10 -756558.924682

# %% [markdown]
# # Polynomial Features

# %%
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.25, random_state=10)

PF = LinearRegression()
PF.fit(x_train, y_train)
PF.predict(x_test)
y_pred2 = PF.predict(x_test)
PF_r2 = r2_score(y_test, y_pred2)
PF_MSE = mean_squared_error (y_test, y_pred2)
PF_inter = LM.intercept_

print("R2 score:", PF_r2)
print("MSE:", PF_MSE)
print(PF_inter)
# Out:
# R2 score: 0.29404976976419983
# MSE: 105515980075.51407
# -756558.9246823956

# %%
coeff_df = pd.DataFrame(LM.coef_,x.columns,columns=['PF_Coefficient'])
coeff_df
# Out:
#                PF_Coefficient
# bedrooms        -3.281921e+04
# bathrooms        1.747693e+04
# sqft_living     -2.718773e+15
# grade            1.221572e+05
# sqft_above       2.718773e+15
# sqft_basement    2.718773e+15

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("PF Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred2, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'PF Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %% [markdown]
# # Decision Tree

# %%
DT = DecisionTreeRegressor(random_state=0).fit(x_train, y_train)
#DT.fit(x_train, y_train)
#DT.predict(x_test)
y_pred3 = DT.predict(x_test)
DT_r2 = r2_score(y_test, y_pred3)
DT_MSE = mean_squared_error (y_test, y_pred3)
#DT_inter = DT.intercept_

print("R2 score:", DT_r2)
print("MSE:", DT_MSE)
#print(DT_inter)
# Out:
# R2 score: 0.3066171405962458
# MSE: 103637577897.11569

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("DT Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred3, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'DT Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %% [markdown]
# # Random Forest

# %%
RF = RandomForestRegressor(n_estimators = 100, random_state = 0).fit(x_train, y_train)
y_pred4 = RF.predict(x_test) 
RF_r2 = r2_score(y_test, y_pred4)
RF_MSE = mean_squared_error (y_test, y_pred4)

print("R2 score:", RF_r2)
print("MSE:", RF_MSE)
# Out:
# R2 score: 0.5842064523301524
# MSE: 62147247514.60822

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("RF Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred4, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'RF Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %% [markdown]
# # KNeighbors

# %%
KNN = KNeighborsRegressor(n_neighbors=5).fit(x_train, y_train)
y_pred5 = KNN.predict(x_test) 
KNN_r2 = r2_score(y_test, y_pred5)
KNN_MSE = mean_squared_error (y_test, y_pred5)

print("R2 score:", KNN_r2)
print("MSE:", KNN_MSE)
# Out:
# R2 score: 0.5084061374546305
# MSE: 73476862792.80106

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("KNN Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred5, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'KNN Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %%
SVR = SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False).fit(x_train,y_train)
y_pred6 = SVR.predict(x_test)
SVR_r2 = r2_score(y_test, y_pred6)
SVR_MSE = mean_squared_error (y_test, y_pred6)

print("R2 score:", SVR_r2)
print("MSE:", SVR_MSE)
# Out:
# R2 score: -0.049231441465055426
# MSE: 156825055266.64438

# %%
plt.xlabel("Historical Price")
plt.ylabel("Predicted Price")
plt.title("SVR Price Prediction")
plt.xticks(rotation=45)
sns.regplot(x=y_test, y=y_pred6, data=df, color="green")
# Out:
# <AxesSubplot:title={'center':'SVR Price Prediction'}, xlabel='price', ylabel='Predicted Price'>

# %%
results = pd.DataFrame({'Model' : ["LM","PF","DT","RF","KNN","SVR"], "r2_score" :[LM_r2, PF_r2, DT_r2, RF_r2, KNN_r2, SVR_r2], "mean_squared_error" :[LM_MSE, PF_MSE, DT_MSE, RF_MSE, KNN_MSE, SVR_MSE]})
results.sort_values(by="r2_score",  ascending=False)
# Out:
#   Model  r2_score  mean_squared_error
# 3    RF  0.584206        6.214725e+10
# 0    LM  0.545042        6.800101e+10
# 4   KNN  0.508406        7.347686e+10
# 2    DT  0.306617        1.036376e+11
# 1    PF  0.294050        1.055160e+11
# 5   SVR -0.049231        1.568251e+11

# %%
objects = ('LM', 'PF', 'DT', 'RF', 'KNN', 'SVR')
y_pos = np.arange(len(objects))
performance = [LM_r2, PF_r2, DT_r2, RF_r2, KNN_r2, SVR_r2]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('model')
plt.xlabel('r2_score')
plt.title('Regressor Performance')

plt.show()

# %%
n_groups = 6
performance_R2 = (LM_r2, PF_r2, DT_r2, RF_r2, KNN_r2, SVR_r2)
performance_MSE = (LM_MSE, PF_MSE, DT_MSE, RF_MSE, KNN_MSE, SVR_MSE)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, performance_R2, bar_width, alpha=opacity, color='b', label='R2')

rects2 = plt.bar(index + bar_width, performance_MSE, bar_width, alpha=opacity, color='g', label='MSE*1e11')

plt.xlabel('Models')
plt.ylabel('Score Types')
plt.title('Model Scores')
plt.xticks(index + bar_width, ('LM', 'PF', 'DT', 'RF', 'KNN', 'SVR'))
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Random Forest provides th best score. Let's save and load this model.

# %%
import pickle

# %%
# save the model to disk
filename = 'kch_RF_model.sav'
pickle.dump(y_pred, open(filename, 'wb')) # wb stands for reading only in binary format

# %%
# load the model from disk
loaded_kch_model = pickle.load(open(filename, 'rb')) # rb stands for reading only in binary format

# %% [markdown]
# # Prediction from loaded model

# %%
coef = np.array(LM.coef_)
print(LM.coef_)
# Out:
# [-3.28192101e+04  1.74769289e+04 -2.71877265e+15  1.22157231e+05
#   2.71877265e+15  2.71877265e+15]

# %%
coeffs = pd.DataFrame(LM.coef_, x.columns,columns=['Coefficient'])
coeffs
# Out:
#                 Coefficient
# bedrooms      -3.281921e+04
# bathrooms      1.747693e+04
# sqft_living   -2.718773e+15
# grade          1.221572e+05
# sqft_above     2.718773e+15
# sqft_basement  2.718773e+15

# %%
inter = LM.intercept_
print(inter)
# Out:
# -756558.9246823956

# %%
def calculate_house_sale_price(bedrooms, bathrooms, sqft_living, grade, sqft_above, sqft_basement, cof):
    
    bedrooms_coef = cof[0]
    bathrooms_coef = cof[1]
    sqft_living_coef = cof[2]
    grade_coef = cof[3]
    sqft_above_coef = cof[4]
    sqft_basement_coef = cof[5]
    
    result = (( bedrooms_coef* bedrooms)
              + ( bathrooms_coef*bathrooms)
              + (sqft_living_coef*sqft_living)
              + (grade_coef* grade)
              + (sqft_above_coef*sqft_above)
              + (sqft_basement_coef*sqft_basement)
              + inter)
    
    return result

# %%
# Let's calculate the net annual sale using some random values!
house_price = calculate_house_sale_price(bedrooms = 2, bathrooms = 2, 
                                     sqft_living = 2000, grade = 7,
                                     sqft_above = 1000,  sqft_basement = 1000,
                                     #inter = LM.intercept_,
                                     cof = LM.coef_)
print("Our house price $:", round(house_price, 2))
# Out:
# Our house price $: 528049.08
